# %%
import weaviate
from weaviate.classes.init import Auth
import requests, json, os
client = weaviate.connect_to_local()

# %%
collection = client.collections.get("DemoCollection2")
collection = client.create_collection("DemoCollection2", "This is a demo collection")

# %%
collection.__dict__
# Out:
# {'_connection': <weaviate.connect.v4.ConnectionV4 at 0x12938b5cd70>,
#  'name': 'DemoCollection2',
#  '_validate_arguments': True,
#  '_config': <weaviate.collections.config.config._ConfigCollectionAsync at 0x12938b5e900>,
#  '_query': <weaviate.collections.query._QueryCollectionAsync at 0x12938bf7b60>,
#  '_CollectionBase__tenant': None,
#  '_CollectionBase__consistency_level': None,
#  '_CollectionBase__properties': None,
#  '_CollectionBase__references': None,
#  '_Collection__cluster': <weaviate.collections.cluster.sync._Cluster at 0x12938acd310>,
#  'aggregate': <weaviate.collections.aggregate._AggregateCollection at 0x12938bf7cb0>,
#  'backup': <weaviate.collections.backups.sync._CollectionBackup at 0x12938bf7a10>,
#  'batch': <weaviate.collections.batch.collection._BatchCollectionWrapper at 0x12938d2eba0>,
#  'config': <weaviate.collections.config.sync._ConfigCollection at 0x12938bf70e0>,
#  'data': <weaviate.collections.data.sync._DataCollection at 0x12938d2ef90>,
# ...
